# %%
import pandas as pd


topics = pd.read_csv('../outputs/topic_annotator.tsv', sep='\t')
topics
# Out:
#                             topic  \
# 0            Business and Finance
# 1            Business and Finance
# 2                     Programming
# 3        Technology and Computing
# 4                       Off-Topic
# ...                           ...
# 68618      Business and Marketing
# 68619           Business and Work
# 68620  Technology and Programming
# 68621         Health and Wellness
# 68622         Health and Medicine
#
#                                                    query
# 0      Summarize the main ideas of Jeff Walker's Prod...
# 1      How to tell if a customer segment is well segm...
# 2      In Java, I want to replace string like This is...
# 3      Metaphorical language is also used to describe...
# 4      Lo and behold! By the grace of divine interven...
# ...                                                  ...
# 68618  Here are 20 more video title ideas:\n\n1. The ...
# 68619  I've made a hub site comprised of various empl...
# ...

# %%
topics['topic'].value_counts()[:50]
# Out:
# topic
# Programming                      8344
# Education and Learning           7909
# Business and Finance             7460
# Technology                       6382
# Technical Support                5419
# Technology and Programming       2952
# Creative Writing                 2463
# Gaming                           1097
# General Knowledge                1048
# Business and Entrepreneurship    1044
# Science and Technology           1003
# Technology and Computing          904
# Health and Wellness               788
# Technical Discussion              682
# Entertainment                     622
# Fiction                           512
# Business and Marketing            481
# Storytelling                      478
# General Chat                      470
# Humor                             460
# Customer Support                  395
# Business and Work                 334
# Professional Development          315
# Job Search                        300
# ...
